# %% [markdown]
# # Canada's Linear Regression Single Variable

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

df =  pd.read_csv('canada_per_capita_income.csv')
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
reg = LinearRegression()

# Reshape the input feature to a 2D array
x = df['year'].values.reshape(-1, 1)

y = df['per capita income (US$)']

reg.fit(x, y)
# Out:
# LinearRegression()

# %%
predict = reg.predict(x)
predict
# Out:
# array([ -134.55966672,   693.9054085 ,  1522.37048373,  2350.83555895,
#         3179.30063417,  4007.7657094 ,  4836.23078462,  5664.69585984,
#         6493.16093506,  7321.62601029,  8150.09108551,  8978.55616073,
#         9807.02123595, 10635.48631118, 11463.9513864 , 12292.41646162,
#        13120.88153685, 13949.34661207, 14777.81168729, 15606.27676251,
#        16434.74183774, 17263.20691296, 18091.67198818, 18920.1370634 ,
#        19748.60213863, 20577.06721385, 21405.53228907, 22233.9973643 ,
#        23062.46243952, 23890.92751474, 24719.39258996, 25547.85766519,
#        26376.32274041, 27204.78781563, 28033.25289085, 28861.71796608,
#        29690.1830413 , 30518.64811652, 31347.11319175, 32175.57826697,
#        33004.04334219, 33832.50841741, 34660.97349264, 35489.43856786,
#        36317.90364308, 37146.3687183 , 37974.83379353])

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# -1632210.7578554575

# %%
reg.predict([[2025]])
# Out:
# array([45431.01947053])

# %%
import matplotlib.pyplot as plt

# Create an array of predicted years from 2017 to 2025
years_to_predict = np.arange(2017, 2026)

# Make predictions for each year
predicted_incomes = [reg.predict([[year]]) for year in years_to_predict]

# Plot the data points and the linear regression line
plt.figure(figsize=(20,10))
plt.scatter(X, y, color='lightgreen', label='Actual Data')
plt.plot(X, reg.predict(X), color='darkred', label='Linear Regression Line')
plt.scatter(years_to_predict, predicted_incomes, color='lightblue', label='Predicted')

plt.xlabel('Year', fontsize=20)
plt.ylabel('Per Capita Income (US$)', fontsize=20)
plt.title('Linear Regression: Actual vs. Predicted Income', fontsize=20)
plt.legend(loc='best', markerscale=1.5, fontsize='x-large')

# Add x-axis and y-axis values
plt.xticks(np.arange(1970, 2030, 1), rotation=45)  # Customize x-axis ticks as needed
plt.yticks(np.arange(0, 40000, 5000))  # Customize y-axis ticks as needed
# plt.grid(True)
plt.show()

# Display predicted incomes for the years 2017 to 2025
for year, income in zip(years_to_predict, predicted_incomes):
    print(f"Predicted income for {year}: {income[0]:.2f}")
# Out:
# Predicted income for 2017: 38803.30
# Predicted income for 2018: 39631.76
# Predicted income for 2019: 40460.23
# Predicted income for 2020: 41288.69
# Predicted income for 2021: 42117.16
# Predicted income for 2022: 42945.62
# Predicted income for 2023: 43774.09
# Predicted income for 2024: 44602.55
# Predicted income for 2025: 45431.02
